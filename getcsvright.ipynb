# %%
df.iloc[1,  2]
# Out:
# 6

# %%
df.iat[1, 2] = 6

# %%
import pandas as pd
pd.set_option('display.max_rows', None)
df = pd.read_csv("customfull2.csv")
df.iloc[:, [0, 1]]
# Out:
#              Name  Engager
# 0          Aatrox        4
# 1            Ahri        4
# 2           Akali        6
# 3          Akshan        3
# 4         Alistar        7
# 5           Amumu        9
# 6          Anivia        2
# 7           Annie        4
# 8        Aphelios        0
# 9            Ashe        4
# 10   Aurelion Sol        2
# 11           Azir        2
# 12           Bard        3
# 13        Belveth        2
# 14     Blitzcrank       10
# 15          Brand        0
# 16          Braum        6
# 17        Caitlyn        0
# 18        Camille       10
# 19     Cassiopeia        1
# 20        ChoGath        1
# 21          Corki        4
# 22         Darius        2
# 23          Diana        8
# 24       Dr.Mundo        8
# 25         Draven        0
# 26           Ekko        7
# 27          Elise        8
# 28        Evelynn        5
# 29         Ezreal        2
# 30   Fiddlesticks        7
# 31          Fiora        4
# 32           Fizz        9
# ...
